# %% [markdown]
# # Singapore HDB Resale Market Intelligence
#
# ## 01 — Data Audit
#
# ### Objective
# Understand the structure, quality, and coverage of the official HDB resale transaction dataset before performing any cleaning or analysis.

# %%
from pathlib import Path

PROJECT_ROOT = next((path for path in [Path.cwd(), *Path.cwd().parents] if (path / "data").is_dir() and (path / "notebooks").is_dir()), None)
if PROJECT_ROOT is None:
    raise FileNotFoundError("Run this notebook from inside the project directory.")

import pandas as pd

# %%
df = pd.read_csv(PROJECT_ROOT / "data" / "raw" / "hdb_resale_raw.csv")

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# ## 1. Dataset Dimensions

# %%
df.shape
# Out:
# (239330, 11)

# %% [markdown]
# ## 2. Column Names

# %%
df.columns.tolist()
# Out:
# ['month',
#  'town',
#  'flat_type',
#  'block',
#  'street_name',
#  'storey_range',
#  'floor_area_sqm',
#  'flat_model',
#  'lease_commence_date',
#  'remaining_lease',
#  'resale_price']

# %% [markdown]
# ## 3. Data Preview

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# ## 4. Data Types and Non-Null Counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239330 entries, 0 to 239329
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                239330 non-null  object
#  1   town                 239330 non-null  object
#  2   flat_type            239330 non-null  object
#  3   block                239330 non-null  object
#  4   street_name          239330 non-null  object
#  5   storey_range         239330 non-null  object
#  6   floor_area_sqm       239330 non-null  float64
#  7   flat_model           239330 non-null  object
#  8   lease_commence_date  239330 non-null  int64
#  9   remaining_lease      239330 non-null  object
#  10  resale_price         239330 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 20.1+ MB

# %% [markdown]
# ## 5. Missing Values

# %%
df.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
(df.isna().mean() * 100).round(2)
# Out:
# month                  0.0
# town                   0.0
# flat_type              0.0
# block                  0.0
# street_name            0.0
# storey_range           0.0
# floor_area_sqm         0.0
# flat_model             0.0
# lease_commence_date    0.0
# remaining_lease        0.0
# resale_price           0.0
# dtype: float64

# %% [markdown]
# ## 6. Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(318)

# %% [markdown]
# ## 7. Numerical Summary

# %%
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count   239330.000000        239330.000000  2.393300e+05
# mean        96.683115          1996.608858  5.342959e+05
# std         24.013807            14.387890  1.919414e+05
# min         31.000000          1966.000000  1.400000e+05
# 25%         81.000000          1985.000000  3.900000e+05
# 50%         93.000000          1997.000000  5.020000e+05
# 75%        112.000000          2012.000000  6.400000e+05
# max        366.700000          2023.000000  1.728000e+06

# %% [markdown]
# ## 8. Categorical Variables

# %%
df["town"].value_counts()
# Out:
# town
# SENGKANG           19368
# PUNGGOL            17331
# WOODLANDS          17049
# TAMPINES           16579
# YISHUN             16248
# JURONG WEST        15686
# BEDOK              12459
# HOUGANG            12086
# CHOA CHU KANG      10744
# BUKIT BATOK        10232
# ANG MO KIO          9655
# BUKIT MERAH         9109
# BUKIT PANJANG       8512
# TOA PAYOH           7864
# SEMBAWANG           7298
# KALLANG/WHAMPOA     7292
# PASIR RIS           6929
# QUEENSTOWN          6545
# GEYLANG             5949
# CLEMENTI            5293
# JURONG EAST         4840
# SERANGOON           4206
# BISHAN              4163
# CENTRAL AREA        1859
# MARINE PARADE       1454
# BUKIT TIMAH          580
# Name: count, dtype: int64

# %%
df["flat_type"].value_counts()
# Out:
# flat_type
# 4 ROOM              101732
# 5 ROOM               58516
# 3 ROOM               56895
# EXECUTIVE            16991
# 2 ROOM                5020
# 1 ROOM                  88
# MULTI-GENERATION        88
# Name: count, dtype: int64

# %%
df["flat_model"].value_counts()
# Out:
# flat_model
# Model A                   86312
# Improved                  58395
# New Generation            29021
# Premium Apartment         26205
# Simplified                 9141
# Apartment                  8522
# Maisonette                 6509
# Standard                   6347
# DBSS                       3798
# Model A2                   2690
# 2-room                      497
# Model A-Maisonette          415
# Adjoined flat               407
# Type S1                     387
# Type S2                     197
# Premium Apartment Loft      139
# Terrace                     123
# Multi Generation             88
# 3Gen                         83
# Improved-Maisonette          32
# Premium Maisonette           22
# Name: count, dtype: int64

# %%
df["storey_range"].value_counts()
# Out:
# storey_range
# 04 TO 06    54868
# 07 TO 09    50124
# 10 TO 12    44707
# 01 TO 03    42020
# 13 TO 15    23132
# 16 TO 18    10838
# 19 TO 21     4687
# 22 TO 24     3266
# 25 TO 27     2040
# 28 TO 30     1339
# 31 TO 33      731
# 34 TO 36      648
# 37 TO 39      527
# 40 TO 42      257
# 43 TO 45       75
# 46 TO 48       52
# 49 TO 51       19
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Time Coverage

# %%
df["month"].min(), df["month"].max()
# Out:
# ('2017-01', '2026-08')
